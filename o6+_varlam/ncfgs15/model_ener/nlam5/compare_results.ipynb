# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import scipy.constants as scc

# %%
d_convRyd2eV=scc.physical_constants['Rydberg constant times hc in eV']
convRyd2eV=d_convRyd2eV[0]
d_kB=scc.physical_constants['Boltzmann constant in eV/K']
kB=d_kB[0]
convcm2Ryd=1./109737.26

# %%
plt.rcParams.update({'font.size': 16})
plt.rcParams['font.sans-serif'] = "FreeSans"
plt.rc('text', usetex=False)

# %%
file1='initer20_maxevals50/latin/seed_4/O15CFGTFDA_20GP50'
file2='initer50_maxevals50/latin/seed_4/O15CFGTFDA_50GP50'
file3='initer20_maxevals80/latin/seed_4/O15CFGTFDA_20GP80'
file4='initer100_maxevals100/latin/seed_5/O15CFGTFDA_100GP100'

# %%
lam1=pd.read_csv(file1+'.dat',sep='\s+',header='infer')
lam2=pd.read_csv(file2+'.dat',sep='\s+',header='infer')
lam3=pd.read_csv(file3+'.dat',sep='\s+',header='infer')
lam4=pd.read_csv(file4+'.dat',sep='\s+',header='infer')

# %%
fig=plt.figure(figsize=(15,15))
ax1=plt.subplot(331)
ax1.set_title('1s',fontsize=22)
plt.plot(lam1['Iteration'],lam1['var_1'],'ro')
plt.plot(lam2['Iteration'],lam2['var_1'],'go')
plt.plot(lam3['Iteration'],lam3['var_1'],'bo')
plt.plot(lam4['Iteration'],lam4['var_1'],'co')
ax2=plt.subplot(332)
ax2.set_title('2s',fontsize=22)
plt.plot(lam1['Iteration'],lam1['var_2'],'ro')
plt.plot(lam2['Iteration'],lam2['var_2'],'go')
plt.plot(lam3['Iteration'],lam3['var_2'],'bo')
plt.plot(lam4['Iteration'],lam4['var_2'],'co')
ax3=plt.subplot(333)
ax3.set_title('2p',fontsize=22)
plt.plot(lam1['Iteration'],lam1['var_3'],'ro')
plt.plot(lam2['Iteration'],lam2['var_3'],'go')
plt.plot(lam3['Iteration'],lam3['var_3'],'bo')
plt.plot(lam4['Iteration'],lam4['var_3'],'co')
ax4=plt.subplot(334)
ax4.set_title('3s',fontsize=22)
plt.plot(lam1['Iteration'],lam1['var_4'],'ro')
plt.plot(lam2['Iteration'],lam2['var_4'],'go')
plt.plot(lam3['Iteration'],lam3['var_4'],'bo')
plt.plot(lam4['Iteration'],lam4['var_4'],'co')
ax5=plt.subplot(335)
ax5.set_title('3p',fontsize=22)
plt.plot(lam1['Iteration'],lam1['var_5'],'ro')
plt.plot(lam2['Iteration'],lam2['var_5'],'go')
plt.plot(lam3['Iteration'],lam3['var_5'],'bo')
plt.plot(lam4['Iteration'],lam4['var_5'],'co')
ax6=plt.subplot(336)
ax6.set_title('J',fontsize=22)
plt.plot(lam1['Iteration'],lam1['Y'],'ro',label='20-50')
plt.plot(lam2['Iteration'],lam2['Y'],'go',label='50-50')
plt.plot(lam3['Iteration'],lam3['Y'],'bo',label='20-80')
plt.plot(lam4['Iteration'],lam4['Y'],'co',label='100-100')
plt.ylim(0.2,0.5)
plt.legend(loc='best',fontsize=16)
# plt.yscale('log')
plt.tight_layout()
plt.show()

# %%
def find_minval(lam):
    minval=lam['Y'].min(axis=0)
    iminval=lam['Y'].idxmin(axis=0)
    return lam.loc[iminval:iminval]

# %%
min_lam1=find_minval(lam1)
min_lam1
# Out:
#     Iteration         Y     var_1   var_2     var_3     var_4     var_5
# 52       53.0  0.230559  1.190644  0.7883  0.460786  1.095386  1.005845

# %%
find_minval(lam2)
# Out:
#     Iteration         Y     var_1     var_2     var_3     var_4     var_5
# 81       82.0  0.228126  1.192286  0.824562  0.386477  1.000337  1.027915

# %%
min_lam3=find_minval(lam3)
min_lam3
# Out:
#     Iteration         Y     var_1     var_2     var_3     var_4     var_5
# 70       71.0  0.230147  1.189039  0.822461  0.440488  1.047704  0.931018

# %%
min_lam4=find_minval(lam4)
min_lam4
# Out:
#      Iteration         Y     var_1     var_2     var_3     var_4     var_5
# 124      125.0  0.231651  1.192155  0.794917  0.392811  1.016777  1.147914

# %%
dum=lam1.sort_values(by='Y')
best20_lam1=dum.iloc[0:20]
best10_lam1=dum.iloc[0:10]
best5_lam1=dum.iloc[0:5]

# %%
dum=lam3.sort_values(by='Y')
best10_lam3=dum.iloc[0:10]
best5_lam3=dum.iloc[0:5]

# %%
dum=lam4.sort_values(by='Y')
best10_lam4=dum.iloc[0:10]
best5_lam4=dum.iloc[0:5]

# %%
fig=plt.figure(figsize=(15,15))
ax1=plt.subplot(331)
ax1.set_title('1s',fontsize=22)
plt.plot(lam1['Iteration'],lam1['var_1'],'ro')
plt.plot(best20_lam1['Iteration'],best20_lam1['var_1'],'go')
plt.plot(best10_lam1['Iteration'],best10_lam1['var_1'],'go')
plt.plot(best5_lam1['Iteration'],best5_lam1['var_1'],'bo')
ax2=plt.subplot(332)
ax2.set_title('2s',fontsize=22)
plt.plot(lam1['Iteration'],lam1['var_2'],'ro')
plt.plot(best20_lam1['Iteration'],best20_lam1['var_2'],'go')
plt.plot(best10_lam1['Iteration'],best10_lam1['var_2'],'go')
plt.plot(best5_lam1['Iteration'],best5_lam1['var_2'],'bo')
ax3=plt.subplot(333)
ax3.set_title('2p',fontsize=22)
plt.plot(lam1['Iteration'],lam1['var_3'],'ro')
plt.plot(best20_lam1['Iteration'],best20_lam1['var_3'],'go')
plt.plot(best10_lam1['Iteration'],best10_lam1['var_3'],'go')
plt.plot(best5_lam1['Iteration'],best5_lam1['var_3'],'bo')
ax4=plt.subplot(334)
ax4.set_title('3s',fontsize=22)
plt.plot(lam1['Iteration'],lam1['var_4'],'ro')
plt.plot(best20_lam1['Iteration'],best20_lam1['var_4'],'go')
plt.plot(best10_lam1['Iteration'],best10_lam1['var_4'],'go')
plt.plot(best5_lam1['Iteration'],best5_lam1['var_4'],'bo')
ax5=plt.subplot(335)
ax5.set_title('3p',fontsize=22)
plt.plot(lam1['Iteration'],lam1['var_5'],'ro')
plt.plot(best20_lam1['Iteration'],best20_lam1['var_5'],'go')
plt.plot(best10_lam1['Iteration'],best10_lam1['var_5'],'go')
plt.plot(best5_lam1['Iteration'],best5_lam1['var_5'],'bo')
ax6=plt.subplot(336)
ax6.set_title('J',fontsize=22)
plt.plot(lam1['Iteration'],lam1['Y'],'ro',label='20-50')
plt.plot(best20_lam1['Iteration'],best20_lam1['Y'],'go',label='20 lowest')
plt.plot(best10_lam1['Iteration'],best10_lam1['Y'],'go',label='10 lowest')
plt.plot(best5_lam1['Iteration'],best5_lam1['Y'],'bo',label='5 lowest')
plt.axvline(min_lam1.iloc[0]['Iteration'],linewidth=0.75,linestyle='--', color='k')
plt.ylim(0.2,0.5)
plt.legend(loc='best',fontsize=16)
# plt.yscale('log')
plt.tight_layout()
plt.show()

# %%
fig=plt.figure(figsize=(15,15))
ax1=plt.subplot(331)
ax1.set_title('1s',fontsize=22)
plt.plot(lam3['Iteration'],lam3['var_1'],'ro')
plt.plot(best10_lam3['Iteration'],best10_lam3['var_1'],'go')
plt.plot(best5_lam3['Iteration'],best5_lam3['var_1'],'bo')
plt.axvline(70,linewidth=0.75,linestyle='--', color='r')
ax2=plt.subplot(332)
ax2.set_title('2s',fontsize=22)
plt.plot(lam3['Iteration'],lam3['var_2'],'ro')
plt.plot(best10_lam3['Iteration'],best10_lam3['var_2'],'go')
plt.plot(best5_lam3['Iteration'],best5_lam3['var_2'],'bo')
plt.axvline(70,linewidth=0.75,linestyle='--', color='r')
ax3=plt.subplot(333)
ax3.set_title('2p',fontsize=22)
plt.plot(lam3['Iteration'],lam3['var_3'],'ro')
plt.plot(best10_lam3['Iteration'],best10_lam3['var_3'],'go')
plt.plot(best5_lam3['Iteration'],best5_lam3['var_3'],'bo')
plt.axvline(70,linewidth=0.75,linestyle='--', color='r')
ax4=plt.subplot(334)
ax4.set_title('3s',fontsize=22)
plt.plot(lam3['Iteration'],lam3['var_4'],'ro')
plt.plot(best10_lam3['Iteration'],best10_lam3['var_4'],'go')
plt.plot(best5_lam3['Iteration'],best5_lam3['var_4'],'bo')
plt.axvline(70,linewidth=0.75,linestyle='--', color='r')
ax5=plt.subplot(335)
ax5.set_title('3p',fontsize=22)
plt.plot(lam3['Iteration'],lam3['var_5'],'ro')
plt.plot(best10_lam3['Iteration'],best10_lam3['var_5'],'go')
plt.plot(best5_lam3['Iteration'],best5_lam3['var_5'],'bo')
plt.axvline(70,linewidth=0.75,linestyle='--', color='r')
ax6=plt.subplot(336)
ax6.set_title('J',fontsize=22)
plt.plot(lam3['Iteration'],lam3['Y'],'ro',label='20-50')
plt.plot(best10_lam3['Iteration'],best10_lam3['Y'],'go',label='10 lowest')
plt.plot(best5_lam3['Iteration'],best5_lam3['Y'],'bo',label='5 lowest')
plt.axvline(min_lam3.iloc[0]['Iteration'],linewidth=0.75,linestyle='--', color='k')
plt.axvline(70,linewidth=0.75,linestyle='--', color='r')
plt.ylim(0.2,0.5)
plt.legend(loc='best',fontsize=16)
# plt.yscale('log')
plt.tight_layout()
plt.show()

# %%
best10_lam1
# Out:
#     Iteration         Y     var_1     var_2     var_3     var_4     var_5
# 52       53.0  0.230559  1.190644  0.788300  0.460786  1.095386  1.005845
# 61       62.0  0.231726  1.189179  0.814902  0.410338  1.075244  0.910472
# 62       63.0  0.232592  1.189453  0.830878  0.405781  1.055643  0.882322
# 66       67.0  0.232982  1.189496  0.834043  0.408959  1.049692  0.884788
# 65       66.0  0.233052  1.189504  0.833846  0.407465  1.050767  0.882489
# 64       65.0  0.233118  1.189512  0.833757  0.406137  1.051458  0.880420
# 63       64.0  0.233396  1.189550  0.834924  0.404952  1.050492  0.878247
# 57       58.0  0.235271  1.188543  0.781381  0.408902  1.176402  0.896199
# 56       57.0  0.236332  1.186941  0.782948  0.405574  1.135112  0.947107
# 50       51.0  0.240695  1.190657  0.789042  0.460572  1.097872  0.496523

# %%
best10_lam3
# Out:
#     Iteration         Y     var_1     var_2     var_3     var_4     var_5
# 70       71.0  0.230147  1.189039  0.822461  0.440488  1.047704  0.931018
# 52       53.0  0.230559  1.190644  0.788300  0.460786  1.095386  1.005845
# 95       96.0  0.230726  1.191564  0.807429  0.242449  1.042593  1.042934
# 94       95.0  0.230789  1.191542  0.807306  0.239091  1.045045  1.044849
# 92       93.0  0.230883  1.191520  0.815487  0.230712  1.184268  1.050851
# 93       94.0  0.230886  1.191474  0.807774  0.234314  1.056301  1.047157
# 61       62.0  0.231726  1.189179  0.814902  0.410338  1.075244  0.910472
# 62       63.0  0.232592  1.189453  0.830878  0.405781  1.055643  0.882322
# 66       67.0  0.232982  1.189496  0.834043  0.408959  1.049692  0.884788
# 65       66.0  0.233052  1.189504  0.833846  0.407465  1.050767  0.882489

# %%
best10_lam4
# Out:
#      Iteration         Y     var_1     var_2     var_3     var_4     var_5
# 124      125.0  0.231651  1.192155  0.794917  0.392811  1.016777  1.147914
# 110      111.0  0.233047  1.188880  0.824773  0.542534  0.928510  1.082437
# 172      173.0  0.234128  1.191049  0.783142  0.327322  1.099110  0.920883
# 163      164.0  0.234138  1.191415  0.781506  0.336410  1.094397  0.913110
# 178      179.0  0.234162  1.190981  0.784097  0.325468  1.098595  0.919647
# 195      196.0  0.234777  1.191003  0.782839  0.313425  1.108315  0.907257
# 118      119.0  0.235420  1.191732  0.775883  0.371407  1.056535  1.210552
# 130      131.0  0.235664  1.190918  0.784871  0.303692  1.052633  0.872542
# 160      161.0  0.235708  1.191522  0.777295  0.318440  1.080009  0.874690
# 158      159.0  0.235715  1.191524  0.777389  0.315149  1.087091  0.875997
